# %% [markdown]
# # LSTM & GRU Stock Prediction
# Notebook de treino com dados do Yahoo Finance

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import torch
import torch.nn as nn

# %%
data = yf.download('AAPL', start='2015-01-01')
close = data['Close']
close.head()

# %%
scaler = MinMaxScaler()
scaled = scaler.fit_transform(close.values.reshape(-1,1))
